# %% [markdown]
# ## **連接GOOGLE DRIVE和下載程式碼**

# %%
import os

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Leo5307/AICUP_Baseline_BoT-SORT.git
# Out:
# Cloning into 'AICUP_Baseline_BoT-SORT'...
# remote: Enumerating objects: 957, done.
# remote: Counting objects: 100% (957/957), done.
# remote: Compressing objects: 100% (732/732), done.
# remote: Total 957 (delta 198), reused 944 (delta 190), pack-reused 0
# Receiving objects: 100% (957/957), 7.87 MiB | 15.09 MiB/s, done.
# Resolving deltas: 100% (198/198), done.

# %% [markdown]
# ## **安裝Anaconda與環境設定**

# %%
# !pwd
# Out:
# /content

# %%
cd ~
# Out:
# /root

# %%
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# !chmod +x Miniconda3-py37_4.8.3-Linux-x86_64.sh
# !time bash ./Miniconda3-py37_4.8.3-Linux-x86_64.sh -b -f -p /usr/local
# !time conda install -q -y -c conda-forge rdkit
# Out:
# --2024-06-11 06:47:43--  https://repo.continuum.io/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.177.84, 104.18.176.84, 2606:4700::6812:b154, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.177.84|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh [following]
# --2024-06-11 06:47:43--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88867207 (85M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.3-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  84.75M  46.0MB/s    in 1.8s
#
# ...

# %%
# !conda create -n botsort python=3.7
# Out:
# done
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.3
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/botsort
#
#   added / updated specs:
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     ca-certificates-2024.3.11  |       h06a4308_0         127 KB
#     certifi-2022.12.7          |   py37h06a4308_0         150 KB
#     ld_impl_linux-64-2.38      |       h1181459_1         654 KB
#     libffi-3.4.4               |       h6a678d5_1         141 KB
#     libgcc-ng-11.2.0           |       h1234567_1         5.3 MB
# ...

# %%
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages')

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# botsort                  /usr/local/envs/botsort

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate botsort

# %%
# !pip install numpy
# Out:
# ...
#      |████████████████████████████████| 15.7 MB 23.7 MB/s
# ...

# %%
cd /content/AICUP_Baseline_BoT-SORT
# Out:
# /content/AICUP_Baseline_BoT-SORT

# %%
pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 62.5 MB 76 kB/s
# ...
#      |████████████████████████████████| 62 kB 1.4 MB/s
# ...
#      |████████████████████████████████| 13.5 MB 80.3 MB/s
# ...
#      |████████████████████████████████| 24.8 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 24.2 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 73.6 MB/s
# ...
#      |████████████████████████████████| 307 kB 87.7 MB/s
# ...
#      |████████████████████████████████| 6.0 MB 74.9 MB/s
# ...
#      |████████████████████████████████| 1.5 MB 80.1 MB/s
# ...
#      |████████████████████████████████| 177 kB 79.4 MB/s
# ...
#      |████████████████████████████████| 4.3 MB 23.3 MB/s
# ...
#      |████████████████████████████████| 11.2 MB 79.4 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 194 kB/s
# ...
#      |████████████████████████████████| 293 kB 79.0 MB/s
# ...
#      |████████████████████████████████| 670 kB 78.5 MB/s
# ...
#      |████████████████████████████████| 14.5 MB 34.7 MB/s
# ...

# %%
# !pip install cython; pip3 install 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# Out:
# ...
#      |████████████████████████████████| 3.6 MB 27.5 MB/s
# ...
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-fbx5fnoz
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-fbx5fnoz
#   Resolved https://github.com/cocodataset/cocoapi.git to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp310-cp310-linux_x86_64.whl size=375614 sha256=b742f970fda24fbf7e64c2749096b1c985a9e43cdfa85a4ba3303113f950c28c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-08ppkt_v/wheels/39/61/b4/480fbddb4d3d6bc34083e7397bc6f5d1381f79acc68e9f3511
# Successfully built pycocotools
# ...
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.7
#     Uninstalling pycocotools-2.0.7:
#       Successfully uninstalled pycocotools-2.0.7
# ...

# %%
# Cython-bbox
# !pip install cython_bbox

# faiss cpu / gpu
# !pip install faiss-cpu
# !pip install faiss-gpu
# Out:
# ...
#   Created wheel for cython-bbox: filename=cython_bbox-0.1.5-cp37-cp37m-linux_x86_64.whl size=100439 sha256=cd4c94cc1de9e79e23fd1b18ceaf2b1a32ddeaf768c9d2084fa349757c6c46df
#   Stored in directory: /root/.cache/pip/wheels/9f/a2/50/57ec763c3f1337e677d9f1a07a1f9ed121b4940fd6fe20848a
# Successfully built cython-bbox
# ...
#      |████████████████████████████████| 17.6 MB 159 kB/s
# ...
#      |████████████████████████████████| 85.5 MB 163 kB/s
# ...

# %% [markdown]
# ## **下載以及處理比賽資料集**

# %%
# !unzip /content/drive/MyDrive/AICUP/datasets.zip -d /content/datasets
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: /content/datasets/train/images/0902_190000_191900/0_00287.jpg
#   inflating: /content/datasets/train/images/0902_190000_191900/3_00331.jpg
#   inflating: /content/datasets/train/images/0902_190000_191900/2_00134.jpg
#   inflating: /content/datasets/train/images/0902_190000_191900/1_00119.jpg
#   inflating: /content/datasets/train/images/0902_190000_191900/6_00119.jpg
#   inflating: /content/datasets/train/images/0902_190000_191900/4_00075.jpg
#   inflating: /content/datasets/train/images/0902_190000_191900/2_00290.jpg
#   inflating: /content/datasets/train/images/0902_190000_191900/6_00315.jpg
#   inflating: /content/datasets/train/images/0902_190000_191900/6_00297.jpg
#   inflating: /content/datasets/train/images/0902_190000_191900/5_00061.jpg
#   inflating: /content/datasets/train/images/0902_190000_191900/6_00205.jpg
#   inflating: /content/datasets/train/images/0902_190000_191900/5_00185.jpg
# ...

# %%
# !pip install opencv-python

# %%
# !pip list
# Out:
# Package                  Version
# ------------------------ --------------------
# absl-py                  2.1.0
# beautifulsoup4           4.12.3
# cachetools               5.3.3
# certifi                  2020.4.5.1
# cffi                     1.14.0
# chardet                  3.0.4
# conda                    4.8.3
# conda-package-handling   1.7.0
# cryptography             2.9.2
# cycler                   0.11.0
# Cython                   3.0.10
# cython-bbox              0.1.5
# easydict                 1.13
# faiss-cpu                1.7.4
# faiss-gpu                1.7.2
# filelock                 3.12.2
# filterpy                 1.4.5
# flatbuffers              24.3.25
# fonttools                4.38.0
# gdown                    4.7.3
# google-auth              2.30.0
# google-auth-oauthlib     0.4.6
# grpcio                   1.62.2
# h5py                     3.8.0
# idna                     2.9
# imageio                  2.31.2
# importlib-metadata       6.7.0
# ...

# %%
# !pwd
# Out:
# /content/AICUP_Baseline_BoT-SORT

# %%
# %cd "./AICUP_Baseline_BoT-SORT"
# Out:
# [Errno 2] No such file or directory: './AICUP_Baseline_BoT-SORT'
# /content/AICUP_Baseline_BoT-SORT

# %%
# !python fast_reid/datasets/generate_AICUP_patches.py --data_path /content/datasets/train
# Out:
# convert /content/datasets/train/images/0902_150000_151900: 100% 2880/2880 [00:21<00:00, 134.45it/s]
# convert /content/datasets/train/images/0902_190000_191900: 100% 2880/2880 [00:15<00:00, 180.08it/s]
# convert /content/datasets/train/images/0903_150000_151900: 100% 1081/1081 [00:07<00:00, 139.23it/s]
# convert /content/datasets/train/images/0903_190000_191900: 100% 2520/2520 [00:13<00:00, 185.11it/s]
# convert /content/datasets/train/images/0924_150000_151900: 100% 2786/2786 [00:23<00:00, 118.77it/s]
# convert /content/datasets/train/images/0924_190000_191900: 100% 2520/2520 [00:15<00:00, 164.23it/s]
# convert /content/datasets/train/images/0925_150000_151900: 100% 2880/2880 [00:24<00:00, 116.04it/s]
# convert /content/datasets/train/images/0925_190000_191900: 100% 2880/2880 [00:18<00:00, 155.52it/s]
# convert /content/datasets/train/images/1015_150000_151900: 100% 2880/2880 [00:22<00:00, 126.72it/s]
# ...

# %%
# !python yolov7/tools/AICUP_to_YOLOv7.py --AICUP_dir ../datasets/train --YOLOv7_dir ../datasets/yolo
# Out:
# copying data: 100% 63894/63894 [00:34<00:00, 1831.07it/s]
# delete_track_id: 100% 29067/29067 [00:02<00:00, 13448.67it/s]
# delete_track_id: 100% 2880/2880 [00:00<00:00, 13739.44it/s]

# %%
pwd
# Out:
# '/content/AICUP_Baseline_BoT-SORT'

# %% [markdown]
# **複製預訓練模型**

# %%
# !mkdir pretrained
# !cp /content/drive/MyDrive/AICUP/mot20_sbs_S50.pth /content/AICUP_Baseline_BoT-SORT/pretrained/mot20_sbs_S50.pth

# %% [markdown]
# ## **訓練 fast reid 模型**

# %%
# !python3 fast_reid/tools/train_net.py --config-file fast_reid/configs/AI_BERT/sbs_S50_report.yml MODEL.DEVICE "cuda:0"
# Out:
# Command Line Args: Namespace(config_file='fast_reid/configs/AI_BERT/sbs_S50_report.yml', dist_url='tcp://127.0.0.1:49152', eval_only=False, machine_rank=0, num_gpus=1, num_machines=1, opts=['MODEL.DEVICE', 'cuda:0'], resume=False)
# [06/10 15:55:34 fastreid]: Rank of current process: 0. World size: 1
# [06/10 15:55:35 fastreid]: Environment info:
# ----------------------  ----------------------------------------------------------------
# sys.platform            linux
# Python                  3.7.7 (default, May  7 2020, 21:25:33) [GCC 7.3.0]
# numpy                   1.21.6
# fastreid                failed to import
# FASTREID_ENV_MODULE     <not set>
# PyTorch                 1.13.1+cu117 @/usr/local/lib/python3.7/site-packages/torch
# PyTorch debug build     False
# GPU available           True
# GPU 0                   NVIDIA L4
# CUDA_HOME               /usr/local/cuda
# Pillow                  9.5.0
# ...

# %% [markdown]
# ## **訓練 YOLO 模型**

# %%
# !python yolov7/train.py --device 0 --batch-size 16 --epochs 50 --data yolov7/data/AIBERT.yaml --img 640 640 --cfg ./final_test.yaml --weights 'pretrained/yolov7-e6e.pt' --name yolov7-AICUP --hyp data/hyp.scratch.custom.yaml
# Out:
# YOLOv7 🚀 9fcfba3 torch 1.13.1+cu117 CUDA:0 (NVIDIA L4, 22699.875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='./final_test.yaml', data='yolov7/data/AIBERT.yaml', device='0', entity=None, epochs=50, evolve=False, exist_ok=False, global_rank=-1, hyp='./yolov7/data/hyp.scratch.custom.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7-AICUP', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov7-AICUP3', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='pretrained/yolov7-e6e.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %% [markdown]
# ## **推論階段（inference）**

# %% [markdown]
# ## **推論訓練集**

# %%
# !unzip /content/drive/MyDrive/AICUP/leaderboard_model.zip -d /content/leaderboard_model
# Out:
# Archive:  /content/drive/MyDrive/AICUP/leaderboard_model.zip
#    creating: /content/leaderboard_model/leaderboard_model/
#    creating: /content/leaderboard_model/leaderboard_model/sbs_50_v2/
#   inflating: /content/leaderboard_model/leaderboard_model/sbs_50_v2/config.yaml
#   inflating: /content/leaderboard_model/leaderboard_model/sbs_50_v2/model_final.pth
#    creating: /content/leaderboard_model/leaderboard_model/yolo/
#   inflating: /content/leaderboard_model/leaderboard_model/yolo/best.pt

# %%
# !bash tools/track_all_timestamps_report.sh --weights "../leaderboard_model/leaderboard_model/yolo/best.pt" --source-dir "../datasets/train/images/" --device "0" --fast-reid-config "../leaderboard_model/leaderboard_model/sbs_50_v2/config.yaml" --fast-reid-weights "../leaderboard_model/leaderboard_model/sbs_50_v2/model_final.pth"
# Out:
# Namespace(ablation=False, agnostic_nms=True, appearance_thresh=0.25, aspect_ratio_thresh=1.6, augment=True, classes=None, cmc_method='sparseOptFlow', conf_thres=0.09, device='0', exist_ok=False, fast_reid_config='../leaderboard_model/leaderboard_model/sbs_50_v2/config.yaml', fast_reid_weights='../leaderboard_model/leaderboard_model/sbs_50_v2/model_final.pth', hide_labels_name=False, img_size=1920, iou_thres=0.6, jde=False, match_thresh=0.5, min_box_area=10, mot20=True, name='0902_150000_151900', new_track_thresh=0.4, nosave=False, project='runs/detect_report', proximity_thresh=0.5, save_conf=False, save_txt=False, source='../datasets/train/images//0902_150000_151900', trace=False, track_buffer=60, track_high_thresh=0.3, track_low_thresh=0.05, update=False, view_img=False, weights=['../leaderboard_model/leaderboard_model/yolo/best.pt'], with_reid=True)
# YOLOv7 🚀 d690947 torch 1.13.1+cu117 CUDA:0 (NVIDIA L4, 22699.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# ...

# %%
# !python tools/datasets/AICUP_to_MOT15.py --AICUP_dir "../datasets/train" --MOT15_dir "./converted_directory"
# Out:
# convert to MOT15 format: 100% 31947/31947 [00:07<00:00, 4172.10it/s]

# %% [markdown]
# **將預測出來的.txt檔案和converted_directory裡的.txt檔案對比即可**

# %% [markdown]
# ## **推論測試集**

# %%
# !unzip -P g4kWASduabVSmgbn3d881 /content/drive/MyDrive/AICUP/32_33_AI_CUP_testdataset.zip -d /content/testdata

# %%
# !bash tools/track_all_timestamps_report.sh --weights "../leaderboard_model/leaderboard_model/yolo/best.pt" --source-dir "../testdata/32_33_AI_CUP_testdataset/AI_CUP_testdata/images/" --device "0" --fast-reid-config "../leaderboard_model/leaderboard_model/sbs_50_v2/config.yaml" --fast-reid-weights "../leaderboard_model/leaderboard_model/sbs_50_v2/model_final.pth"

# %% [markdown]
# **將預測出來的 .txt 檔壓縮後上傳上去官網即可**
